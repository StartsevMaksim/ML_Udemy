# %%
import pandas as pd
import numpy as np
from datetime import datetime
import sqlalchemy
import oracledb

# %%
df_Persons = pd.read_csv('tips.csv')

# %%
df_Persons.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df_Persons[['total_bill', 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
df_Persons['total_bill'].between(10, 20, inclusive='neither')
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df_Movies = pd.read_csv('movie_scores.csv')

# %%
df_Movies.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df_Movies[df_Movies['pre_movie_score'].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
 dfMpg = pd.read_csv('mpg.csv')

# %%
four_cyl = dfMpg[dfMpg['cylinders'].isin([4, 8])]
four_cyl.groupby(['model_year', 'cylinders']).max().sort_index(level='model_year', ascending=False)
# Out:
#                        mpg  displacement horsepower  weight  acceleration  \
# model_year cylinders
# 82         4          44.0         156.0          ?    3035          24.6
# 81         8          26.6         350.0        105    3725          19.0
#            4          39.1         156.0          ?    3230          20.7
# 80         4          46.6         156.0          ?    3250          23.7
# 79         8          23.9         360.0         90    4360          22.2
#            4          37.3         151.0         90    3190          24.8
# 78         8          20.2         318.0        145    4080          15.5
#            4          43.1         156.0         97    2855          21.5
# 77         8          17.5         400.0        190    4335          19.0
#            4          36.0         151.0         96    2755          18.6
# 76         8          17.5         351.0        180    4380          15.0
# ...

# %%
dfMpg[dfMpg['mpg'].isin(dfMpg.groupby('model_year')['mpg'].max())]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 18   27.0          4          97.0         88    2130          14.5
# 29   27.0          4          97.0         88    2130          14.5
# 30   28.0          4         140.0         90    2264          15.5
# 50   28.0          4         116.0         90    2123          14.0
# 54   35.0          4          72.0         69    1613          18.0
# 55   27.0          4          97.0         60    1834          19.0
# 81   28.0          4          97.0         92    2288          17.0
# 83   28.0          4          98.0         80    2164          15.0
# 84   27.0          4          97.0         88    2100          16.5
# 117  29.0          4          68.0         49    1867          19.5
# 131  32.0          4          71.0         65    1836          21.0
# 141  29.0          4          98.0         83    2219          16.5
# 145  32.0          4          83.0         61    2003          19.0
# ...

# %%
data_one = {'Country': ['USA', 'RU', 'GBR'], 'Population': [330, 140, 50]}
data_two = {'GDP': [1203, 120, 130]}
data_three = {'Country': ['RU', 'CHN'], 'GDP': [390, 1300]}

df_1 = pd.DataFrame(data_one)
df_2 = pd.DataFrame(data_two)
df_3 = pd.DataFrame(data_three)

# %%
df_4 = pd.concat([df_1, df_2], axis=1)

# %%
pd.concat([df_4, df_3], axis=0)
# Out:
#   Country  Population   GDP
# 0     USA         330  1203
# 1      RU         140   120
# 2     GBR          50   130
# 0     JAP         125   140
# 1     CHN        1400  1300

# %%
pd.merge(df_1, df_3, how='outer', on='Country')
# Out:
#   Country  Population     GDP
# 0     CHN         NaN  1300.0
# 1     GBR        50.0     NaN
# 2      RU       140.0   390.0
# 3     USA       330.0     NaN

# %%
names = pd.Series(['andrew@email.com', 'max@gmail.com', 'sasha@gmail.com', '54Vas@x.ru'])

# %%
names.str.split('@', expand=True)
# Out:
#         0          1
# 0  andrew  email.com
# 1     max  gmail.com
# 2   sasha  gmail.com
# 3   54Vas       x.ru

# %%
myyear = 2024
mym = 12
myd = 31

# %%
mydate = datetime(myyear, mym, myd)

# %%
mydate.year
# Out:
# 2024

# %%
myser = pd.Series(['2000-01-01', None])

# %%
pd.to_datetime(myser)
# Out:
# 0   2000-01-01
# 1          NaT
# dtype: datetime64[ns]

# %%
date_1 = '22--Dec--2000'
pd.to_datetime(date_1, format='%d--%b--%Y')
# Out:
# Timestamp('2000-12-22 00:00:00')

# %%
data_1_out = pd.DataFrame({'Country': ['USA', 'China', 'Russia', 'Germany', 'Kongo', 'Japan'],
                       'Population': [330, 1300, 140, 50, 80, 80],
                       'GDP': [1200, 1500, 300, 400, 120, 450]})

# %%
data_csv = pd.read_csv('example.csv')
data_csv
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
data_1.to_csv('output.csv', index=False)

# %%
url = 'https://en.wikipedia.org/wiki/World_population'

# %%
tables = pd.read_html(url)

# %%
data_2 = tables[5]
data_2.columns = ['###', 'Most populous countries', '2000', '2015', '2030', '###']

# %%
data_2
# Out:
#    Most populous countries  2000  2015  2030
# 1                    China  1270  1376  1416
# 2                    India  1053  1311  1528
# 3            United States   283   322   356
# 4                Indonesia   212   258   295
# 5                 Pakistan   136   208   245
# 6                   Brazil   176   206   228
# 7                  Nigeria   123   182   263
# 8               Bangladesh   131   161   186
# 9                   Russia   146   146   149
# 10                  Mexico   103   127   148
# 11             World total  6127  7349  8501

# %%
data_1.to_html('ex_html.html', index=False)

# %%
data_1 = pd.read_excel('excel_exp.xlsx')

# %%
data_1_out.to_excel('excel_out.xlsx', sheet_name='Fisrt', index=False)

# %%
data_1_crm = pd.read_csv('Sales_Funnel_CRM.csv')
data_1_pivot = pd.pivot(data=data_1_crm, index='Company', columns='Product', values='Licenses')

# %%
data_1_pivot.iloc[[0]]
# Out:
# Product  Analytics  GPS Positioning  Prediction  Tracking
# Company
# Google       150.0              NaN       150.0     300.0
